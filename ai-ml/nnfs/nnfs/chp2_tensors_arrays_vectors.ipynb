# %% [markdown]
# ### Tensors, Arrays, Vectors

# %% [markdown]
# - A list of lists is **homologous** if each list along a dimension is identially long, and this must be true for each dimension
# - A matrix is a 2D array
# - Shape counts by starting from the outer most brackets and working inwards
# ![image.png](attachment:84cd994a-215e-4b5d-889d-05394d88ae0d.png)
# - A **tensor** object is an object that can be represented as an array
# - An array is an ordered homologous container for numbers
